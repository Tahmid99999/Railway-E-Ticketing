# %%
train_numbers = [701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 717, 718, 719, 720, 721, 722, 723, 724, 729, 730, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 749, 750, 751, 752, 757, 758, 767, 768, 771, 772, 773, 774, 777, 778, 781, 782, 785, 787, 788, 789, 790]
tmp=0;
ln=len(train_numbers)
tknum=45;
for i in range(ln):
    if(tmp<=ln):
        tr=train_numbers[tmp];
        for j in range(6):
            tknum+=1;
            print("({},'UMA', {} , 190, 'false','S_CHAIR','{}UMA{}')".format(tr,tknum,tr,tknum))
        tmp+=1;
# Out:
# (701,'UMA', 46 , 190, 'true','S_CHAR','701UMA46')
# (701,'UMA', 47 , 190, 'true','S_CHAR','701UMA47')
# (701,'UMA', 48 , 190, 'true','S_CHAR','701UMA48')
# (701,'UMA', 49 , 190, 'true','S_CHAR','701UMA49')
# (701,'UMA', 50 , 190, 'true','S_CHAR','701UMA50')
# (701,'UMA', 51 , 190, 'true','S_CHAR','701UMA51')
# (702,'UMA', 52 , 190, 'true','S_CHAR','702UMA52')
# (702,'UMA', 53 , 190, 'true','S_CHAR','702UMA53')
# (702,'UMA', 54 , 190, 'true','S_CHAR','702UMA54')
# (702,'UMA', 55 , 190, 'true','S_CHAR','702UMA55')
# (702,'UMA', 56 , 190, 'true','S_CHAR','702UMA56')
# (702,'UMA', 57 , 190, 'true','S_CHAR','702UMA57')
# (703,'UMA', 58 , 190, 'true','S_CHAR','703UMA58')
# (703,'UMA', 59 , 190, 'true','S_CHAR','703UMA59')
# (703,'UMA', 60 , 190, 'true','S_CHAR','703UMA60')
# (703,'UMA', 61 , 190, 'true','S_CHAR','703UMA61')
# (703,'UMA', 62 , 190, 'true','S_CHAR','703UMA62')
# (703,'UMA', 63 , 190, 'true','S_CHAR','703UMA63')
# (704,'UMA', 64 , 190, 'true','S_CHAR','704UMA64')
# ...
